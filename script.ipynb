# %%
from google.colab import userdata
import os
from dotenv import load_dotenv
from pathlib import Path
# !pip install python-dotenv
from getpass import getpass

########################################################################################################################################################
                                            # IN GOOGLE COLAB

                    ############################################################################
# # without .env file
# os.environ['LEETCODE_USERNAME'], os.environ['LEETCODE_USERNAME_2'], os.environ['LEETCODE_USERNAME_3']  = userdata.get('LEETCODE_USERNAME'),userdata.get('LEETCODE_USERNAME_2'), userdata.get('LEETCODE_USERNAME_3')
# print(os.environ.get('LEETCODE_USERNAME_2'))

                    ############################################################################

# # with .env file
# with open(".env", "w") as f:
#     f.write(f"""
# LEETCODE_USERNAME={os.environ.get('LEETCODE_USERNAME')}
# LEETCODE_USERNAME_2={os.environ.get('LEETCODE_USERNAME_2')}
# LEETCODE_USERNAME_3={os.environ.get('LEETCODE_USERNAME_3')}
# """.strip())
# load_dotenv()
# print(f"Verified User 3: {os.getenv('LEETCODE_USERNAME_3')}")

########################################################################################################################################################
                                            # IN GITHUB CODESPACE

                    ############################################################################

# repository secrets in codespace
# https://github.com/Gitforcode-debug/didactic-barnacle/settings/secrets/codespaces/new

########################################################################################################################################################
                                            # GETPASS

# Using getpass for each variable individually
os.environ['LEETCODE_USERNAME'] = getpass("Enter LEETCODE_USERNAME: ")
os.environ['LEETCODE_USERNAME_2'] = getpass("Enter LEETCODE_USERNAME_2: ")
os.environ['LEETCODE_USERNAME_3'] = getpass("Enter LEETCODE_USERNAME_3: ")

# Verification
print(f"Successfully set LEETCODE_USERNAME_2: {os.environ.get('LEETCODE_USERNAME_2')}")
# Out:
# ...
# Successfully set LEETCODE_USERNAME_2:
